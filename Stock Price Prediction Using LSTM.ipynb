# %% [markdown]
# <a href="https://colab.research.google.com/github/PUNNYA-P-GAUR/Machine-Learning/blob/main/Stock%20Price%20Prediction%20Using%20LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=["Date"])

# %%
import matplotlib.pyplot as plt
df["High"][:'2016'].plot(figsize=(16, 4), legend=True)
df["High"]['2017':].plot(figsize=(16, 4), legend=True)
plt.legend(['Training set (Before 2017)', 'Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
trainning_set = df[:'2016'].iloc[:,1:2].values
test_set = df['2017':].iloc[:,1:2].values

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(trainning_set)

# %%
X_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
  X_train.append(training_set_scaled[i - 60:i, 0])
  y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units=80, return_sequences=True))
regressor.add(Dropout(0.1))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=30))
regressor.add(Dropout(0.3))

regressor.add(Dense(units=1))


regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 20s 15ms/step - loss: 0.0241
# Epoch 2/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0081
# Epoch 3/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0069
# Epoch 4/50
# 85/85 [==============================] - 2s 28ms/step - loss: 0.0069
# Epoch 5/50
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0061
# Epoch 6/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0064
# Epoch 7/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0059
# Epoch 8/50
# 85/85 [==============================] - 1s 12ms/step - loss: 0.0056
# Epoch 9/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0054
# Epoch 10/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0045
# Epoch 11/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0049
# Epoch 12/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0047
# Epoch 13/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0039
# Epoch 14/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0042
# Epoch 15/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 16/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 17/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0034
# Epoch 18/50
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 19/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0033
# Epoch 20/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0031
# Epoch 21/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0030
# Epoch 22/50
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 23/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0028
# Epoch 24/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0027
# Epoch 25/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0025
# Epoch 26/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0027
# Epoch 27/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0025
# Epoch 28/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 29/50
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0022
# Epoch 30/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0023
# Epoch 31/50
# 85/85 [==============================] - 2s 19ms/step - loss: 0.0024
# Epoch 32/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0021
# Epoch 33/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 34/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 35/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0021
# Epoch 36/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 37/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0021
# Epoch 38/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0019
# Epoch 39/50
# 85/85 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 40/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0019
# Epoch 41/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0019
# Epoch 42/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0018
# Epoch 43/50
# 85/85 [==============================] - 2s 18ms/step - loss: 0.0018
# Epoch 44/50
# 85/85 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 45/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 46/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 47/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 48/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 49/50
# 85/85 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 50/50
# 85/85 [==============================] - 1s 17ms/step - loss: 0.0017

# %%
# pre-processing the data
dataset_total = pd.concat((df["High"][:'2016'],df["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# making the test data
X_test = []
for i in range(60,len(inputs)):
  X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 [==============================] - 3s 9ms/step

# %%
def plot_prediction(test,prediction):
    plt.plot(test,color='red',label="Real IBM Stock Price")
    plt.plot(prediction, color="blue",label="predicted IBM Stock price")
    plt.title("IBM Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("IBM Stock Price")
    plt.legend()
    plt.show()
# now we'll use this function to visualize our test and predicted data

plot_prediction(test_set,predicted_stock_price)

# %%
from sklearn.metrics import mean_squared_error
import math
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test,predicted))
    print("The root mean sqaured error is {}.".format(rmse))

# %%
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean sqaured error is 2.6053399436289744.
